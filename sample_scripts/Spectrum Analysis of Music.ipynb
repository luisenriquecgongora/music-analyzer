# %%
import librosa
import math
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

# %% [markdown]
# ## READING ANALYSIS

# %%
x, sr = librosa.load('./worldholdon_bobsinclair.mp3')
print("READING ANALYSIS")
print('Sample Rate - ', '{} Hz'.format(sr))
print('Number of Samples - ', '{}'.format(x.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-7542f4b4e962> in <module>
# ----> 1 x, sr = librosa.audioread('./worldholdon_bobsinclair.mp3')
#       2 print("READING ANALYSIS")
#       3 print('Sample Rate - ', '{} Hz'.format(sr))
#       4 print('Number of Samples - ', '{}'.format(x.shape[0]))
#
# AttributeError: module 'librosa' has no attribute 'audioread'

# %% [markdown]
# ## TIME ANALYSIS

# %%
print("TIME ANALYSIS")
mins = math.floor(x.shape[0]/(sr*60))
secs = math.floor((x.shape[0]/sr)%(60))
print('Duration - ', '{}:{}'.format(mins,secs))
# Out:
# TIME ANALYSIS
# Duration -  3:37

# %% [markdown]
# ## SAMPLE ANALYSIS (4 seconds)

# %%
seconds_of_analysis = 5
samples_of_analysis = seconds_of_analysis * sr
print ('Number of Seconds to Analyze - ', '{}'.format(seconds_of_analysis))
print ('Number of Samples to Take- ', '{}'.format(samples_of_analysis))
# Out:
# Number of Seconds to Analyze -  5
# Number of Samples to Take-  110250

# %% [markdown]
# ## Fourier Transform

# %%
X = librosa.stft(x[0:samples_of_analysis])
Xdb = librosa.amplitude_to_db(abs(X),ref=np.max)
print ('Hertz Divisions- ', '{}'.format(Xdb.shape[0]))
print ('Time divisions- ', '{}'.format(Xdb[1].shape[0]))
# Out:
# Hertz Divisions-  1025
# Time divisions-  216

# %% [markdown]
# ## Spectrogram Visualization

# %%
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, y_axis='log', x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
plt.show()
